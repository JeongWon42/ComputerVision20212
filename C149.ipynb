# %% [markdown]
# ## 1.4.9 Contours in OpenCV

# %%
import numpy as np 
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('opencv.jpg')
imgray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
imgray = 255-imgray

# %%
plt.figure(figsize = (15,15))
plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(imgray,cmap = 'gray')
plt.title('Gray'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
ret,thresh = cv2.threshold(imgray,8,255,cv2.THRESH_BINARY)

# %%
plt.figure(figsize = (15,15))
plt.subplot(1,2,1),plt.imshow(opening,cmap = 'gray')
plt.title('imgraplt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(opening,cmap = 'gray')
plt.title('s'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-380167cb84e3> in <module>
#       1 plt.figure(figsize = (15,15))
# ----> 2 plt.subplot(1,2,1),plt.imshow(opening,cmap = 'gray')
#       3 plt.title('opening'), plt.xticks([]), plt.yticks([])
#       4 plt.subplot(1,2,2),plt.imshow(opening,cmap = 'gray')
#       5 plt.title('s'), plt.xticks([]), plt.yticks([])
#
# NameError: name 'opening' is not defined
